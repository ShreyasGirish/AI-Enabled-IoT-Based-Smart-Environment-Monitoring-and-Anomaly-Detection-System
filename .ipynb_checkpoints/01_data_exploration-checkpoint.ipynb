# %%
## Cannonical sensor data (downloaded from kaggle)
Each row represents sensor readings captured at a specific timestamp.
| Column Name   | Type      | Description |
|--------------|-----------|-------------|
| timestamp    | datetime  | Time at which data was recorded |
| temperature  | float     | Ambient temperature in °C (DHT11) |
| humidity     | float     | Relative humidity in % (DHT11) |
| distance     | float     | Distance measured by ultrasonic sensor in cm |


## Notes
- `timestamp` is mandatory and must be converted to datetime
- All sensor values are numeric
- Distance values change with human presence or object movement
- Additional sensors can be added as new columns without changing the pipeline

# %%
import pandas as pd
df=pd.read_csv("iot_telemetry_data.csv")

# %%
df.head()
df.dtypes
# Out:
# ts          float64
# humidity    float64
# motion         bool
# temp        float64
# dtype: object

# %%
df['ts'].head(1)
# Out:
# 0    1.590000e+09
# Name: ts, dtype: float64

# %%
df.head(4)
# Out:
#              ts   humidity  motion       temp
# 0  1.590000e+09  51.000000   False  22.700000
# 1  1.590000e+09  76.000000   False  19.700001
# 2  1.590000e+09  50.900000   False  22.600000
# 3  1.590000e+09  76.800003   False  27.000000

# %%
df['timestamp']=pd.to_datetime(df['ts'], unit='s')

# %%
df[['timestamp']].head()
# Out:
#             timestamp
# 0 2020-05-20 18:40:00
# 1 2020-05-20 18:40:00
# 2 2020-05-20 18:40:00
# 3 2020-05-20 18:40:00
# 4 2020-05-20 18:40:00

# %%
df['temperature']=(df['temp']-32)*5/9

# %%
df['temperature'].head()
# Out:
# 0   -5.166667
# 1   -6.833333
# 2   -5.222222
# 3   -2.777778
# 4   -5.222222
# Name: temperature, dtype: float64

# %%
df['distance'] = df['motion'].apply(lambda x: 50 if x else 200)

# %%
df[['motion', 'distance']].head()
# Out:
#    motion  distance
# 0   False       200
# 1   False       200
# 2   False       200
# 3   False       200
# 4   False       200

# %%
df.head()
# Out:
#              ts   humidity  motion       temp           timestamp  \
# 0  1.590000e+09  51.000000   False  22.700000 2020-05-20 18:40:00
# 1  1.590000e+09  76.000000   False  19.700001 2020-05-20 18:40:00
# 2  1.590000e+09  50.900000   False  22.600000 2020-05-20 18:40:00
# 3  1.590000e+09  76.800003   False  27.000000 2020-05-20 18:40:00
# 4  1.590000e+09  50.900000   False  22.600000 2020-05-20 18:40:00
#
#    temperature  distance
# 0    -5.166667       200
# 1    -6.833333       200
# 2    -5.222222       200
# 3    -2.777778       200
# 4    -5.222222       200

# %%
final_df=df[['timestamp', 'temperature', 'humidity', 'distance']]

# %%
final_df.head()
# Out:
#             timestamp  temperature   humidity  distance
# 0 2020-05-20 18:40:00    -5.166667  51.000000       200
# 1 2020-05-20 18:40:00    -6.833333  76.000000       200
# 2 2020-05-20 18:40:00    -5.222222  50.900000       200
# 3 2020-05-20 18:40:00    -2.777778  76.800003       200
# 4 2020-05-20 18:40:00    -5.222222  50.900000       200

# %%
final_df.dtypes
# Out:
# timestamp      datetime64[ns]
# temperature           float64
# humidity              float64
# distance                int64
# dtype: object
